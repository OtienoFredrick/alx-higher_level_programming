# %%
import urllib.request

# %%
with urllib.request.urlopen("https://www.google.com/search?gs_ssp=eJzj4tTP1TcwNMooz1VgNGB0YPDizU7Nq0xUSMwsKk-sLAYAeZYI3w&q=kenya+airways&rlz=1C1GCEB_enKE1081KE1081&oq=kenya&gs_lcrp=EgZjaHJvbWUqEAgDEC4YxwEYsQMY0QMYgAQyBggAEEUYPDINCAEQLhiDARixAxiABDIGCAIQRRg7MhAIAxAuGMcBGLEDGNEDGIAEMgYIBBBFGDwyBggFEEUYPDIGCAYQRRg9MgYIBxBFGD3SAQgzMTY4ajBqN6gCALACAA&sourceid=chrome&ie=UTF-8") as response:
    html = response.read()

# %%
print(html)
# Out:
# b'<!doctype html><html lang="sw-KE"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>kenya airways - Tafuta na Google</title><script nonce="qKpXTjD-37XfO4Re8mLuWA">(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if(a.tagName==="A"){a=a.getAttribute("data-nohref")==="1";break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){window.google=window.google||{};var a=window.performance&&window.performance.timing&&"navigationStart"in window.performance.timing,b=google.stvsc&&google.stvsc.ns,c=a?b||window.performance.timing.navigationStart:void 0,d=google.stvsc&&google.stvsc.rs
# ...

# %%
pip install shutil
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement shutil (from versions: none)
# ERROR: No matching distribution found for shutil
# Note: you may need to restart the kernel to use updated packages.

# %%
import shutil 
import tempfile
import urllib.request

# %%
with urllib.request.urlopen('http://python.org/') as response:
    with tempfile.NamedTemporaryFile(delete=False) as temp_file:
        shutil.copyfileobj(response, temp_file)
with open(temp_file.name) as html:
    pass

# %%
import urllib.request

req = urllib.request.Request('http://python.org/')
with urllib.request.urlopen(req) as response:
    the_page = response.read()

# %%
print(the_page)
# Out:
# b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xed}\xebr\x1bG\x92\xee\x7fE\xcc;\x94\xa1X\x91\x1a\xab\x01\x82wQ$<\x92L\xc9\xf4\xe8B\x9b\x94\xb5{\xbc\nE\xa3\xd1\x00\x9a\x04\xba\xa1\xbe\x90\x84g&\xe2\xbc\xc6y\xbd}\x92\xfd2\xab\xaa\xbb\xfa\n\x80\xa25\xf6\t\xed\xacE\xf4\xad*++o\x95\x95\x99u\xf8\xcd p\xe2\xf9\xcc\x15\xe3x:\xe9\xdd;\xfc\xc6\xb2~\xf5\x86b\x12\x8b\x93c\xb1\xf7\xa1\'\x848\xa4G\xc2\x99\xd8Qt\xd4\xf2\x03\xeb"\x12\x9e\xbb\x8bW,\xcf\xdd\x93\x7f\xf6\xe5\x9f\xc7-~\xff\x9b_]\x7f\xe0\r?XV\xd6`\xdaZ]\x83U-\xe1]\xfa\xbf\xba\x06\xf7\x19<z\xa1\n\xc2\x1cL\xf2=\xfdoe\x83#\x1e2\xda$\x1c\xf4\xcaM\xb6\xc4\xc4\xf6GG-\xd7o\x89\x81\x17\x1e\xb5&qH\xe3\xa5\xd7s\r\xde;\x1c\xbb\xf6\xa0wO\x82nY\xe2e\x10\x8c&\xae\x88\xed\x91X\x1f\xe1\xdf\xf6E\xf4P\x10r\xf8\x8d\xc8\t\xbdY,\xech\xee;"\n\x9d\xa3\xd68\x8eg\xd1A\xa7s}}\xdd\x1e\xf1\xb7\xf8hj\xfb\xf6\xc8\r\xdbN0\xedP#\x9d\x8b\xe8;op\xf4\xd2:\x7f\xb1\xb5\xf3_/\x1e?\xff\xe5\x87V\xef\xb0#[\xcb5-/\x84\xb8\xf6\xfcAp\xdd\x1e\xd8\xb1\xfd\xca\x9e\xbb\xa18*\xdf\xfa\xe7?\x
# ...

# %%
import urllib.parse
import urllib.request

# %%
url = 'http://www.someserver.com/cgi-bin/register.cgi'
values = {'name': 'Michael Foord',
         'location': 'Northampton',
         'language': 'Python'}
data = urllib.parse.urlencode(values)
data = data.encode('ascii') # data should be bytes
req = urllib.request.Request(url, data)
with urllib.request.urlopen(req) as response:
    the_page = response.read()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       6 data = data.encode('ascii') # data should be bytes
#       7 req = urllib.request.Request(url, data)
# ----> 8 with urllib.request.urlopen(req) as response:
#       9     the_page = response.read()
#
# File /usr/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# ...

# %%
import urllib.parse
import urllib.request

url = 'http://www.someserver.com/cgi-bin/register.cgi'
values = {'name' : 'Michael Foord',
          'location' : 'Northampton',
          'language' : 'Python' }

data = urllib.parse.urlencode(values)
data = data.encode('ascii') # data should be bytes
req = urllib.request.Request(url, data)
with urllib.request.urlopen(req) as response:
   the_page = response.read()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[14], line 12
#      10 data = data.encode('ascii') # data should be bytes
#      11 req = urllib.request.Request(url, data)
# ---> 12 with urllib.request.urlopen(req) as response:
#      13    the_page = response.read()
#
# File /usr/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# ...

# %%
import urllib.request
import urllib.parse
data = {}
data['name'] = 'Somebody Here'
data['location'] = 'Northampton'
data ['language'] = 'Python'
url_values = urllib.parse.urlencode(data)
print(url_values) # The order may defer from below.
#name=somebody+Here&language = Python&location=Northampton
url = 'http://www.example.com/example.cgi'
full_url = url + '?' + url_values
data = urllib.request.urlopen(full_url)
# Out:
# name=Somebody+Here&location=Northampton&language=Python
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[18], line 12
#      10 url = 'http://www.example.com/example.cgi'
#      11 full_url = url + '?' + url_values
# ---> 12 data = urllib.request.urlopen(full_url)
#
# File /usr/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# ...

# %%
import urllib.parse
import urllib.request
url = 'http://www.someserver.com/cgi-bin/register.cgi'
user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
values = {'name': 'Michael Foord',
           'location': 'Northampton',
            'Language': 'Python'}
headers = {'user-agent': user_agent}
data = urllib.parse.urlencode(values)
data = data.encode('ascii')
req = urllib.request.Request(url, values, headers)
with urllib.request.urlopen(req) as response:
    the_page = response.open
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 12
#      10 data = data.encode('ascii')
#      11 req = urllib.request.Request(url, values, headers)
# ---> 12 with urllib.request.urlopen(req) as response:
#      13     the_page = response.open
#
# File /usr/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# ...

# %%
req= urllib.request.Request('http://www.pretend_server.org')
try: urllib.request.urlopen(req)
except urllib.error.URLError as e:
    print(e.reason)
# Out:
# [Errno -2] Name or service not known

# %%
req = urllib.request.Request('http://www.python.org/fish.html')
try: 
    urllib.request.urlopen(req)
except urllib.error.HTTPError as e:
    print(e.code)
    print(e.read())
# Out:
# 404
# ...
